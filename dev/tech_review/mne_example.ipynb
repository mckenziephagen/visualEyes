# %% [markdown]
# ### Initialization

# %%
from mne.io import read_raw_eyelink
from mne.preprocessing.eyetracking import read_eyelink_calibration
from mne.viz.eyetracking import plot_gaze
import mne
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plot gaze data

# %%
# Define file path
example_file = '/Users/Brenda/Desktop/538mtlP1.asc' # change this to the path of your file

# Read the raw data
raw_asc = read_raw_eyelink(example_file)

# Define events
epochs = mne.Epochs(raw_asc, baseline=None)

# Retrieve the calibration data (will return empty list if no calibration was performed during the session)
calibration = read_eyelink_calibration(example_file,
                                       screen_resolution=(1920, 1080),
                                       screen_size=(0.8013, 0.6984),
                                       screen_distance=1.2)[0]
# Out:
# Loading /Users/Brenda/Desktop/538mtlP1.asc
# Pixel coordinate data detected.Pass `scalings=dict(eyegaze=1e3)` when using plot method to make traces more legible.
# Pupil-size area detected.
# Used Annotations descriptions: ['Block_1', 'Block_10', 'Block_2', 'Block_3', 'Block_4', 'Block_5', 'Block_6', 'Block_7', 'Block_8', 'Block_9', 'SYNCTIME', 'fixation', 'saccade']
# Ignoring annotation durations and creating fixed-duration epochs around annotation onsets.
# Not setting metadata
# 674 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading calibration data from /Users/Brenda/Desktop/538mtlP1.asc

# %%
# some info of asc file
raw_asc
# Out:
# <RawEyelink | 538mtlP1.asc, 3 x 113783 (227.6 s), ~2.6 MB, data loaded>

# %%
# calibration info
calibration
# Out:
# Calibration |
#   onset: -3.988 seconds
#   model: HV5
#   eye: right
#   average error: 0.39 degrees
#   max error: 0.75 degrees
#   screen size: (0.8013, 0.6984) meters
#   screen distance: 1.2 meters
#   screen resolution: (1920, 1080) pixels

# %%
# epoch info
epochs

# TODO: what are the event counts?
# Out:
# <Epochs | 290 events (all good), -0.2 – 0.5 s (baseline off), ~7 kB, data not loaded,
#  'Block_1': 1
#  'Block_10': 1
#  'Block_2': 1
#  'Block_3': 1
#  'Block_4': 1
#  'Block_5': 1
#  'Block_6': 0
#  'Block_7': 1
#  'Block_8': 1
#  'Block_9': 0
#  and 3 more events ...>

# %%
# plot gaze
cmap = plt.get_cmap('viridis')
plot_gaze(epochs, calibration=calibration, cmap=cmap)

# TODO: how are bad epochs defined?
# Out:
# Using data from preloaded Raw for 674 events and 351 original time points ...
# 384 bad epochs dropped
